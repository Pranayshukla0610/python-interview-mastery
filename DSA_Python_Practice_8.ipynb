# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/python-interview-mastery/blob/main/DSA_Python_Practice_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Find Maximum and Minimum Element in an Array

arr = list(map(int, input("Enter an array:").split()))

maximum = arr[0]
minimum = arr[0]

for num in arr:
  if num > maximum:
    maximum = num

  if num < minimum:
    minimum = num

print("Maximum Element:", maximum)
print("Minimum Element:", minimum)
# Out:
# Enter an array:12 45 7 89 34 21
# Maximum Element: 89
# Minimum Element: 7

# %%
#Reverse an Array (In-place)
#Problem

#Reverse the array without using another array.

arr = list(map(int, input("Enter an array:").split()))

left = 0
right = len(arr) - 1

while left < right:
  arr[left], arr[right] = arr[right], arr[left]
  left += 1
  right -= 1

print("Reversed Array:",arr)
# Out:
# Enter an array:1 2 3 4 5
# Reversed Array: [5, 4, 3, 2, 1]

# %%
#Second Largest Element

arr = list(map(int, input("Enter array elements: ").split()))

largest = float('-inf')
second_largest = float('-inf')

for num in arr:

    if num > largest:

        second_largest = largest
        largest = num

    elif num > second_largest and num != largest:

        second_largest = num

print("Largest:", largest)
print("Second Largest:", second_largest)
# Out:
# Enter array elements: 5 20 25 40 36
# Largest: 40
# Second Largest: 36

# %%
#Second Smallest Element

arr = list(map(int, input("Enter array elements: ").split()))

smallest = float('inf')
second_smallest = float('inf')

for num in arr:

    if num < smallest:

        second_smallest = smallest
        smallest = num

    elif num < second_smallest and num != smallest:

        second_smallest = num

print("Smallest:", smallest)
print("Second Smallest:", second_smallest)
# Out:
# Enter array elements: 18 8 5 23 43 35
# Smallest: 5
# Second Smallest: 8

# %%
#Check if Array is Sorted

arr = list(map(int, input("Enter array elements: ").split()))

is_sorted = True

for i in range (1, len(arr)):
  if arr[i] < arr[i - 1]:
    is_sorted = False
    break

if is_sorted:
  print("Array is sorted")
else:
  print("Array is not sorted")
# Out:
# Enter array elements: 1 2 3 4 5
# Array is sorted

# %%
#Move All Zeros to the End
arr = list(map(int, input("Enter an array:").split()))

result = []

for i in range(len(arr)):
  if arr[i] > 0:
    result.append(arr[i])

for i in range(len(arr)):
  if arr[i] == 0:
    result.append(arr[i])


print(result)
# Out:
# Enter an array:1 0 5 7 8 0 9 0 4 3 0 2
# [1, 5, 7, 8, 9, 4, 3, 2, 0, 0, 0, 0]

# %%
#Left Rotate Array by d Positions

arr = list(map(int, input("Enter array elements: ").split()))
d = int(input("Enter number of positions to rotate: "))

d = d % len(arr)

arr = arr[d:] + arr[:d]

print("Rotated Array:",arr)
# Out:
# Enter array elements: 1 2 3 4 5 6
# Enter number of positions to rotate: 2
# Rotated Array: [3, 4, 5, 6, 1, 2]
