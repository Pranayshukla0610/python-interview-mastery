# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/python-interview-mastery/blob/main/DSA_Array_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Find the Largest Element in an Array
#Input:

#[10, 25, 7, 45, 18]

#Output:

#45

num = list(map(int,input("Enter numbers:").split()))
max_num = num[0]

for i in range(1,len(num)):
  if num[i] > max_num:
    max_num = num[i]

print(max_num)
# Out:
# Enter numbers:10 25 7 45 18
# 45

# %%
#Find the Second Largest Element
#Input:

#[10, 25, 7, 45, 18]

#Output:

#25

num = list(map(int, input("Enter numbers:").split()))

largest = float('-inf')
second_largest = float('-inf')

for i in range(len(num)):
  if num[i] > largest:
    second_largest = largest
    largest = num[i]
  elif num[i] > second_largest and num[i] != largest:
    second_largest = num[i]

print(second_largest)
# Out:
# Enter numbers:10 25 7 45 18
# 25

# %%
#Reverse an Array
#Input:

#[1, 2, 3, 4, 5]

#Output:

#[5, 4, 3, 2, 1]

num = list(map(int, input("Enter numbers:").split()))

l = 0
r = len(num)-1

while l < r:
  num[l], num[r] = num[r], num[l]
  l += 1
  r -= 1

print("Reversed Array:",num)
# Out:
# Enter numbers:1 2 3 4 5
# Reversed Array: [5, 4, 3, 2, 1]

# %%
#Move All Zeros to the End
#Input:

#[0, 1, 0, 3, 12]

#Output:

#[1, 3, 12, 0, 0]

arr = list(map(int, input("Enter numbers:").split()))

result = []

for i in range(len(arr)):
  if arr[i] != 0:
    result.append(arr[i])

for i in range(len(arr)):
  if arr[i] == 0:
    result.append(0)

print(result)
# Out:
# Enter numbers:0 1 0 3 12
# [1, 3, 12, 0, 0]
