# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/python-interview-mastery/blob/main/Python_Logical_Practice_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Find the Second Largest Element

arr = list(map(int, input("Enter an array:").split()))

largest = second_largest = float('-inf')

for num in arr:
  if num > largest:
    second_largest = largest
    largest = num
  elif num > second_largest and num != largest:
    second_largest = num

print("Second Largest Element:",second_largest)
# Out:
# Enter an array:2 3 5 9 8 7
# Second Largest Element: 8

# %%
#Find the Second Smallest Element

arr = list(map(int, input("Enter an array:").split()))

smallest = second_smallest = float('inf')

for num in arr:
  if num < smallest:
    second_smallest = smallest
    smallest = num
  elif num < second_smallest and num != smallest:
    second_smallest = num

print("Second Smallest Element:",second_smallest)
# Out:
# Enter an array:1 3 4 6 5 4
# Second Smallest Element: 3

# %%
#Check if an Array is a Palindrome

arr = list(map(int, input("Enter an array:").split()))

if arr == arr[::-1]:
  print("Array is a Palindrome")
else:
  print("Array is not a Palindrome")
# Out:
# Enter an array:2 8 9 1
# Array is not a Palindrome

# %%
#Reverse an Array Without Using reverse()

arr = list(map(int, input("Enter an array:").split()))

left = 0
right = len(arr) - 1

while left < right:
  arr[left], arr[right] = arr[right], arr[left]
  left += 1
  right -+ 1

print(arr)
# Out:
# Enter an array:3 5 8 9 2
# [2, 3, 5, 8, 9]

# %%
#Find the Sum of Digits of a Number

arr = int(input("Enter a number:"))

total = 0

while arr > 0:
  total += arr % 10
  arr //= 10

print(total)
# Out:
# Enter a number:191
# 11

# %%
#Reverse a Number

num = int(input("Enter a number:"))

reverse = 0

while num > 0:
  digit = num % 10
  reverse = reverse * 10 + digit
  num //= 10

print(reverse)
# Out:
# Enter a number:243
# 342

# %%
#Check whether a number is perfect number

num = int(input("Enter a number:"))

total = 0

for i in range(1,num):
  if num % i == 0:
    total += i

if total == num:
  print("Perfect Number")
else:
  print("Not Perfect Number")
# Out:
# Enter a number:181
# Not Perfect Number

# %%
#Find the GCD (Greatest Common Divisor)

a = int(input("Enter a number:"))
b = int(input("Enter a number:"))

while b != 0:
  a, b = b, a % b

print(a)
# Out:
# Enter a number:346
# Enter a number:512
# 2
